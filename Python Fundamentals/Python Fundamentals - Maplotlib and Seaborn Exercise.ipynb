# %% [markdown]
# # Maplotlib and Seaborn Exercise Solutions

# %% [markdown]
# ### Exercise 1
# - Import numpy, pandas, matplotlib.pyplot, and seaborn
# - Import the file "Loan_Home.csv" into a pandas dataframe
# - Show all the columns in the dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

loan = pd.read_csv('Loan_Home.csv')
loan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ### Exercise 2
# Use matplotlib to create a scatter plot that include the data from "ApplicantIncome" column and "LoanAmount" column:
# - Set the chart size to be 12,8
# - Name the scatter plot "Home Loan Analysis"
# - Name the x axis "Applicant Income" and the y axis "LoanAmount"

# %%
plt.figure(figsize=(12,8))
plt.title('Home Loan Analysis')
plt.scatter(x='ApplicantIncome', y='LoanAmount', data=loan)
plt.xlabel('Applicant Income')
plt.ylabel('LoanAmount')
# Out:
# Text(0, 0.5, 'LoanAmount')

# %% [markdown]
# ### Exercise 3
# Use Seaborn to create a histogram chart for the data in the "ApplicantIncome" column:
# - Distrubute the data into 8 bins
# - Set the bins to be purple
# - Remove the Guassian kernel

# %%
sns.distplot(loan['ApplicantIncome'], bins=8, kde=False, color='purple')
# Out:
# C:\Users\Guilherme\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncome'>

# %% [markdown]
# ### Exercise 4
# Use seaborn to create a bar plot to examine the total "LoanAmount" grouped by "Property_Area". Set the color pallette as "bright".

# %%
sns.barplot(data=loan, y='LoanAmount', x='Property_Area', palette='bright')
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='LoanAmount'>

# %% [markdown]
# ### Exercise 5
# Use seaborn to create a box plot for the "LoanAmount" data grouped by "Education".

# %%
sns.boxplot(loan['LoanAmount'], loan['Education'])
# Out:
# C:\Users\Guilherme\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanAmount', ylabel='Education'>
