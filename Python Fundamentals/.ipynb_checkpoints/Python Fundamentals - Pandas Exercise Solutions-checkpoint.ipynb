# %% [markdown]
# # Pandas Exercise Solutions

# %% [markdown]
# ### Exercise 1
# Import Pandas and create a series with the following data:
# - Create a list "numbers" with six numbers: 2, 5, 18, 7, 21, 9
# - Create a list "markers" with six strings: a, b, c, d, e, f
# - Apply the list "numbers" to a series and use "markers" as index

# %%
import pandas as pd
numbers = [2, 5, 18, 7, 21, 9]
markers = ['a', 'b', 'c', 'd', 'e', 'f']
pd.Series(data = numbers, index = markers)
# Out:
# a     2
# b     5
# c    18
# d     7
# e    21
# f     9
# dtype: int64

# %% [markdown]
# ### Exercise 2
# Import the data in "Retail_Sales.csv"  to a dataframe called "retail_df1", and print the following:
# - Check how many rows and columns are in this dataframe
# - Show the summary statistics of the retail_df dataframe
# - Show the first 5 rows of the dataframe
# - Show the unique values in the "Product Type" column

# %%
# Import csv file to a dataframe
retail_df1 = pd.read_csv('Retail_Sales.csv')

# Check the number of rows and columns
retail_df1.shape
# Out:
# (1775, 6)

# %%
# Show the summary statistics of this dataframe
retail_df1.describe()
# Out:
#        Net Quantity   Gross Sales    Discounts      Returns  Total Net Sales
# count   1775.000000   1775.000000  1775.000000  1775.000000      1775.000000
# mean       3.712676    199.671746    -6.317623    -5.385437       187.968687
# std        6.243078    464.880638    20.903517    46.654269       414.547039
# min       -1.000000      0.000000  -594.000000 -1609.000000      -106.250000
# 25%        1.000000     48.000000    -6.000000     0.000000        44.800000
# 50%        2.000000    100.000000     0.000000     0.000000        96.000000
# 75%        4.000000    185.500000     0.000000     0.000000       184.750000
# max       96.000000  14935.000000     0.000000     0.000000     12732.000000

# %%
# Show the first 5 rows of the dataframe
retail_df1.head(5)
# Out:
#       Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0  Art & Sculpture            34      14935.0    -594.00  -1609.0
# 1           Basket            13       3744.0    -316.80      0.0
# 2           Basket            12       3825.0    -201.60   -288.0
# 3           Basket            17       3035.0     -63.25      0.0
# 4  Art & Sculpture            47       2696.8     -44.16      0.0
#
#    Total Net Sales
# 0         12732.00
# 1          3427.20
# 2          3335.40
# 3          2971.75
# 4          2652.64

# %%
# Show the unique values in the "Product Type" column
retail_df1['Product Type'].unique()
# Out:
# array(['Art & Sculpture', 'Basket', 'Christmas', 'Home Decor',
#        'Recycled Art', 'Jewelry', 'Skin Care', 'Kitchen', 'Textiles',
#        'Accessories', 'Fair Trade Gifts', 'One-of-a-Kind', 'Soapstone',
#        'Music', 'Furniture', 'Kids', nan, 'Easter', 'Gift Baskets'],
#       dtype=object)

# %% [markdown]
# ### Exercise 3
# - Import the csv file "Retail_Sales_2.csv" to the dataframe "retail_df2"
# - Combine "retail_df1" and "retail_df2" into a new dataframe "retail_df". Make sure the join them side by side
# - Show the first 5 rows of the new dataframe

# %%
# Import Retail_Sales_2.csv
retail_df2 = pd.read_csv('Retail_Sales_2.csv')

# Combine retail_df1 and retail_df2 side by side
retail_df = pd.concat([retail_df1, retail_df2], axis = 1)

# Show the first 5 rows of the new dataframe
retail_df.head()
# Out:
#       Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0  Art & Sculpture            34      14935.0    -594.00  -1609.0
# 1           Basket            13       3744.0    -316.80      0.0
# 2           Basket            12       3825.0    -201.60   -288.0
# 3           Basket            17       3035.0     -63.25      0.0
# 4  Art & Sculpture            47       2696.8     -44.16      0.0
#
#    Total Net Sales  Sales ID
# 0         12732.00     10834
# 1          3427.20     10835
# 2          3335.40     10836
# 3          2971.75     10837
# 4          2652.64     10838

# %% [markdown]
# ### Exercise 4
# - Add a column "Price Per Unit" which is the Total Net Sales divided by the Net Quantity
# - Remove the column "Discounts" from the dataframe
# - View the first 5 rows after the changes

# %%
# Add a column to the dataframe
retail_df['Price Per Unit'] = retail_df['Total Net Sales'] / retail_df['Net Quantity']

# Remove a column and reassign the dataframe to save the change
retail_df = retail_df.drop('Discounts', axis = 1)

# View the first 5 rows
retail_df.head()
# Out:
#       Product Type  Net Quantity  Gross Sales  Returns  Total Net Sales  \
# 0  Art & Sculpture            34      14935.0  -1609.0         12732.00
# 1           Basket            13       3744.0      0.0          3427.20
# 2           Basket            12       3825.0   -288.0          3335.40
# 3           Basket            17       3035.0      0.0          2971.75
# 4  Art & Sculpture            47       2696.8      0.0          2652.64
#
#    Price Per Unit
# 0      374.470588
# 1      263.630769
# 2      277.950000
# 3      174.808824
# 4       56.439149

# %% [markdown]
# ### Exercise 5
# - Show all the rows when the Net Quantity is larger than 50
# - Show all the rows when the Product Type is Jewelry

# %%
retail_df[retail_df['Net Quantity']>50]
# Out:
#        Product Type  Net Quantity  Gross Sales  Returns  Total Net Sales  \
# 7         Christmas            90       2160.0      0.0          2114.41
# 22  Art & Sculpture            58       1392.0      0.0          1356.00
# 23        Christmas            58       1392.0      0.0          1346.40
# 24          Jewelry            96       1400.0    -56.0          1302.00
# 37          Kitchen            69       1104.0      0.0          1078.40
# 47  Art & Sculpture            59       1062.0      0.0          1028.40
#
#     Price Per Unit
# 7        23.493444
# 22       23.379310
# 23       23.213793
# 24       13.562500
# 37       15.628986
# 47       17.430508

# %%
## Edited direction to match jewelry
retail_df[retail_df['Product Type'] == 'Jewelry']
# Out:
#      Product Type  Net Quantity  Gross Sales  Returns  Total Net Sales  \
# 15        Jewelry            33       1584.0      0.0          1516.83
# 17        Jewelry            32       1536.0      0.0          1459.20
# 24        Jewelry            96       1400.0    -56.0          1302.00
# 71        Jewelry            18        912.0    -48.0           818.40
# 79        Jewelry            16        768.0      0.0           736.80
# 81        Jewelry            16        768.0      0.0           734.40
# 83        Jewelry            15        720.0      0.0           710.40
# 89        Jewelry            25        700.0      0.0           664.20
# 90        Jewelry            24        672.0      0.0           643.99
# 99        Jewelry            13        624.0      0.0           604.80
# 102       Jewelry            42        602.0    -14.0           580.99
# 113       Jewelry            40        616.0    -56.0           548.80
# 130       Jewelry             9        522.0      0.0           500.40
# 134       Jewelry            11        528.0      0.0           494.42
# 137       Jewelry            10        480.0      0.0           480.00
# 148       Jewelry            17        476.0      0.0           457.80
# 158       Jewelry             5        440.0      0.0           440.00
# 160       Jewelry            16        448.0      0.0           439.60
# 173       Jewelry            29        462.0    -56.0           397.59
# 211       Jewelry            11        360.0      0.0           340.60
# 217       Jewelry             7        336.0      0.0           332.85
# 228       Jewelry            10        340.0      0.0           321.40
# 249       Jewelry            11        308.0      0.0           296.79
# 251       Jewelry             6        300.0      0.0           295.60
# 254       Jewelry            21        378.0    -84.0           291.20
# Art & Sculpture       4.234421   268.001780  -8.770979 -8.545786
# Basket                2.651543   261.008167  -8.320181 -8.057514
# Christmas             7.876712   212.000000  -4.728630 -9.178082
# Easter                1.000000    38.000000  -3.800000  0.000000
# Fair Trade Gifts      3.928571    80.642857  -1.904643  0.000000
# Furniture             1.687500   127.125000 -10.565000  0.000000
# Gift Baskets          1.000000    19.500000   0.000000  0.000000
# Home Decor            3.083969   206.981298  -7.566489 -3.231679
# Jewelry               4.719048   147.847619  -4.599286 -2.424762
# Kids                  2.222222    60.920635  -1.851746  0.000000
# Kitchen               5.024845    99.975155  -2.677702 -2.037702
# Music                 3.379310    91.155172  -2.834138 -4.910690
# One-of-a-Kind         1.000000   181.666667  -5.999167  0.000000
# Recycled Art          4.304348   164.904348  -3.853913  0.000000
# Skin Care             9.181818   237.227273  -3.427273  0.000000
# Soapstone             2.970149    71.574627  -1.446418 -1.037313
# Textiles              3.071429   134.928571  -8.064286 -6.928571
#
#                   Total Net Sales      Sales ID
# Product Type
# Accessories             97.061026  11849.179487
# Art & Sculpture        250.685015  11665.952522
# Basket                 244.630472  11515.375681
# Christmas              198.093288  11702.876712
# Easter                  34.200000  12316.000000
# Fair Trade Gifts        78.738214  12072.357143
# Furniture              116.560000  11700.500000
# Gift Baskets            19.500000  12524.000000
# Home Decor             196.183130  11632.603053
# Jewelry                140.823571  11858.595238
# Kids                    59.068889  12129.507937
# Kitchen                 95.259752  11970.944099
# Music                   83.410345  12025.310345
# One-of-a-Kind          175.667500  11381.916667
# Recycled Art           161.050435  11784.782609
# Skin Care              233.800000  11753.909091
# Soapstone               69.090896  12077.805970
# Textiles               119.935714  11809.000000

# %%
retail_df.groupby('Product Type').describe()
# Out:
#                  Net Quantity                                             \
#                         count      mean        std  min  25%  50%    75%
# Product Type
# Accessories              39.0  2.153846   3.856222  1.0  1.0  1.0   2.00
# Art & Sculpture         337.0  4.234421   6.686981  1.0  1.0  2.0   4.00
# Basket                  551.0  2.651543   3.166040  0.0  1.0  1.0   3.00
# Christmas                73.0  7.876712  12.711483  0.0  2.0  4.0  10.00
# Easter                    1.0  1.000000        NaN  1.0  1.0  1.0   1.00
# Fair Trade Gifts         28.0  3.928571   5.583896  1.0  1.0  2.0   3.00
# Furniture                16.0  1.687500   0.704154  1.0  1.0  2.0   2.00
# Gift Baskets              1.0  1.000000        NaN  1.0  1.0  1.0   1.00
# Home Decor              131.0  3.083969   3.309748  1.0  1.0  2.0   3.00
# Jewelry                 210.0  4.719048   8.998252  0.0  1.0  2.0   4.00
# Kids                     63.0  2.222222   1.782029  1.0  1.0  2.0   3.00
# Kitchen                 161.0  5.024845   7.935640 -1.0  1.0  2.0   6.00
# Music                    29.0  3.379310   3.858329  1.0  1.0  2.0   4.00
# One-of-a-Kind            12.0  1.000000   0.000000  1.0  1.0  1.0   1.00
# Recycled Art             23.0  4.304348   7.730899  1.0  1.0  2.0   2.50
# Skin Care                11.0  9.181818  11.539655  1.0  2.0  4.0   9.50
# Soapstone                67.0  2.970149   2.564148  0.0  1.0  2.0   4.00
# Textiles                 14.0  3.071429   2.400778  0.0  2.0  2.0   3.75
#
#                        Gross Sales              ... Total Net Sales            \
#                    max       count        mean  ...             75%       max
